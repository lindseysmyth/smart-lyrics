# %%
import lyricsgenius
genius = lyricsgenius.Genius("XN6f6ECwHaLNf0dun2Sobkx6bp5ZwoIllko41uM-2qb7ONKqGpx4rKunAsVwtvcS", timeout=100, skip_non_songs = True)

# %% [markdown]
# ### 4 Songs per Genre/Gender

# %%
pop_female_artists = ['Adele', 'Ariana Grande']
pop_male_artists = [    "Ed Sheeran",    "Justin Bieber"]
rock_female_artists = [    "Janis Joplin",    "Stevie Nicks"]
rock_male_artists = [    "Bruce Springsteen",    "Mick Jagger"]
rap_female_artists = [    "Cardi B",    "Nicki Minaj"]
rap_male_artists = ["Snoop Dogg", "Kendrick Lamar"]
country_female_artists = [    "Dolly Parton",    "Shania Twain"]
country_male_artists = [    "Johnny Cash",    "Willie Nelson"]
alternative_indie_female_artists = [    "Björk",    "Fiona Apple"]
alternative_indie_male_artists = [    "Bon Iver",    "Father John Misty"]
rnb_female_artists = [    "Destiny's Child",    "India.Arie"]
rnb_male_artists = [    "Michael Jackson",    "Prince"]
EDM_female_artists = [    "Alison Wonderland",    "Rezz"]
EDM_male_artists = [    "Calvin Harris",    "David Guetta"]
metal_female_artists = [    "Lzzy Hale (Halestorm)",    "Angela Gossow (Arch Enemy)"]
metal_male_artists = [    "James Hetfield (Metallica)",    "Ozzy Osbourne (Black Sabbath)"]

# %%
import pandas as pd
col_names = ["MUSIC GENRE", "ARTIST GENDER"]
name = "SONG "
for i in range(1, 5):
    col_names.append(name + str(i))
dataset = pd.DataFrame(columns=col_names)
dataset.head()

#pop_female_artists
base_record = ["POP", "FEMALE"]
for female_artist in pop_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["POP", "MALE"]
for male_artist in pop_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ROCK", "FEMALE"]
for female_artist in rock_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ROCK", "MALE"]
for male_artist in rock_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RAP", "FEMALE"]
for female_artist in rap_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RAP", "MALE"]
for male_artist in rap_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["COUNTRY", "FEMALE"]
for female_artist in country_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["COUNTRY", "MALE"]
for male_artist in country_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ALTERNATIVE INDIE", "FEMALE"]
for female_artist in alternative_indie_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ALTERNATIVE INDIE", "MALE"]
for male_artist in alternative_indie_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RnB", "FEMALE"]
for female_artist in rnb_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RnB", "MALE"]
for male_artist in rnb_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["EDM", "FEMALE"]
for female_artist in edm_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["EDM", "MALE"]
for male_artist in edm_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["METAL", "FEMALE"]
for female_artist in metal_female_artists:
    artist = genius.search_artist(female_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["METAL", "MALE"]
for male_artist in metal_male_artists:
    artist = genius.search_artist(male_artist, max_songs=2, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

dataset.head()
# for cur in pop_female_artists:
#     artist = genius.search_artist(cur, max_songs=1, sort='popularity')
#     songs = artist.songs
#     for song in songs:
#         pop_female_songs.append(song.lyrics)

# print(pop_female_songs)
# Out:
# Searching for songs by Adele...
#
# Song 1: "Hello"
# Song 2: "Easy On Me"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.
# Searching for songs by Ariana Grande...
#
# Song 1: "​thank u, next"
# Song 2: "7 rings"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.
# 6
# Searching for songs by Ed Sheeran...
#
# Song 1: "Shape of You"
# Song 2: "Perfect"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.
# Searching for songs by Justin Bieber...
#
# Song 1: "Love Yourself"
# Song 2: "Baby"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.
# 6
# Searching for songs by Janis Joplin...
#
# Song 1: "Me and Bobby McGee"
# Song 2: "Mercedes Benz"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.
# Searching for songs by Stevie Nicks...
#
# Song 1: "Edge of Seventeen"
# Song 2: "Stand Back"
#
# Reached user-specified song limit (2).
# Done. Found 2 songs.
# 6
# Searching for songs by Bruce Springsteen...
#
# ...

# %%
dataset.head()
# Out:
#   MUSIC GENRE ARTIST GENDER  \
# 0         POP        FEMALE
# 1         POP          MALE
# 2        ROCK        FEMALE
# 3        ROCK          MALE
# 4         RAP        FEMALE
#
#                                               SONG 1  \
# 0  [TranslationsTürkçePortuguêsPortuguêsEspañolFr...
# 1  [TranslationsTürkçeEspañolPortuguêsΕλληνικάDeu...
# 2  [Me, and, Bobby, McGee, Lyrics[Verse, 1], Bust...
# 3  [Born, in, the, U.S.A., Lyrics[Verse, 1], Born...
# 4  [TranslationsTürkçeEnglishСрпскиРусскийRomânăP...
#
#                                               SONG 2  \
# 0  [TranslationsTürkçeไทย, /, Phasa, ThaiSvenskaE...
# 1  [TranslationsTürkçeEspañolPortuguêsItalianoΕλλ...
# 2  [Mercedes, Benz, Lyrics[Intro], I'd, like, to,...
# 3  [Born, to, Run, Lyrics[Verse, 1], In, the, day...
# 4  [TranslationsEspañolFrançaisNederlandsBodak, Y...
#
#                                               SONG 3  \
# 0  [TranslationsTürkçeSvenskaEspañolРусскийPortug...
# ...

# %%
a = dataset.loc[0]["SONG 1"]

# %%
import os
file_path = os.path.join(os.path.expanduser('~'), 'Downloads', 'lyrics.csv')

# Convert the DataFrame to a CSV file and save it to the Downloads folder
dataset.to_csv(file_path, index=False)

print(f'The CSV file has been saved to {file_path}')
# Out:
# The CSV file has been saved to /Users/lindseysmyth/Downloads/lyrics.csv

# %% [markdown]
# ### 20 Songs per Genre/Gender

# %%
pop_female_artists = ['Adele', 'Ariana Grande', 'Beyoncé', 'Billie Eilish', 'Britney Spears', 'Christina Aguilera', 'Dua Lipa', 'Halsey', 'Jennifer Lopez', 'Katy Perry', 'Lady Gaga', 'Demi Lovato', 'Pussycat Dolls', 'Miley Cyrus', 'P!nk', 'Rihanna', 'Selena Gomez', 'Shakira', 'Kelly Clarkson', 'Gwen Stefani']
pop_male_artists = [    "Ed Sheeran",    "Justin Bieber",    "The Weeknd",    "Shawn Mendes",    "Harry Styles",    "Backstreet Boys",    "Bruno Mars",    "Charlie Puth",    "Sam Smith",    "Adam Levine",    "Lil Nas X",    "Justin Timberlake",    "John Legend",    "Chris Brown",    "Zayn Malik",    "Niall Horan",    "Lauv",    "Jonas Brothers",    "NSYNC",    "Nick Jonas"]
rock_female_artists = [    "Janis Joplin",    "Stevie Nicks",    "Joan Jett",    "Pat Benatar",    "Tina Turner",    "Debbie Harry",    "Chrissie Hynde",    "Patti Smith",    "Bonnie Raitt",    "Annie Lennox",    "Grace Slick",    "Alanis Morissette",    "Dolores O'Riordan",    "Fiona Apple",    "Joni Mitchell",    "Sheryl Crow",    "Marianne Faithfull",    "Lucinda Williams",    "PJ Harvey",    "Courtney Love"]
rock_male_artists = [    "Bruce Springsteen",    "Mick Jagger",    "David Bowie",    "Elvis Presley",    "Kurt Cobain",    "Eddie Vedder",    "Bob Dylan",    "Paul McCartney",    "Robert Plant",    "Freddie Mercury",    "Tom Petty",    "Neil Young",    "Billy Joel",    "Bono",    "Iggy Pop",    "Lou Reed",    "Eddie Van Halen",    "Roger Daltrey",    "Eric Clapton",    "Jimmy Page"]
rap_female_artists = [    "Cardi B",    "Nicki Minaj",    "Megan Thee Stallion",    "Lizzo",    "Missy Elliott",    "Lauryn Hill",    "Queen Latifah",    "Remy Ma",    "Eve",    "Lil Kim",    "Doja Cat",    "Saweetie",    "City Girls",    "Flo Milli",    "Mulatto",    "Asian Doll",    "Rico Nasty",    "Tierra Whack",    "Kari Faux",    "Noname"]
rap_male_artists = ["Snoop Dogg", "Kendrick Lamar", "J. Cole", "Travis Scott", "Post Malone", "Lil Wayne", "Eminem", "Jay-Z", "Kanye West", "Future", "Lil Baby", "DaBaby", "Tyler, The Creator", "Big Sean", "Nas", "Kurupt", "OutKast", "Young Thug", "A$AP Rocky", "Tupac Shakur"]
country_female_artists = [    "Dolly Parton",    "Shania Twain",    "Reba McEntire",    "Carrie Underwood",    "Miranda Lambert",    "Faith Hill",    "Dixie Chicks",    "Martina McBride",    "Loretta Lynn",    "Patsy Cline",    "Tammy Wynette",    "Trisha Yearwood",    "Rosanne Cash",    "Emmylou Harris",    "Alison Krauss",    "Kacey Musgraves",    "Mary Chapin Carpenter",    "Lee Ann Womack",    "LeAnn Rimes",    "Gretchen Wilson"]
country_male_artists = [    "Johnny Cash",    "Willie Nelson",    "Merle Haggard",    "George Jones",    "Hank Williams",    "Garth Brooks",    "Kenny Rogers",    "Alan Jackson",    "Waylon Jennings",    "Keith Urban",    "Tim McGraw",    "Blake Shelton",    "Luke Bryan",    "Brad Paisley",    "Eric Church",    "Chris Stapleton",    "Zac Brown Band",    "Florida Georgia Line",    "Old Dominion",    "Brooks & Dunn"]
alternative_indie_female_artists = [    "Björk",    "Fiona Apple",    "PJ Harvey",    "St. Vincent",    "Liz Phair",    "Tori Amos",    "Angel Olsen",    "Beach House",    "Cat Power",    "Feist",    "Grimes",    "Haim",    "Julien Baker",    "Lana Del Rey",    "Lorde",    "Mitski",    "Phoebe Bridgers",    "The Cranberries",    "Soccer Mommy",    "Waxahatchee"]
alternative_indie_male_artists = [    "Bon Iver",    "Father John Misty",    "Arcade Fire",    "The National",    "Sufjan Stevens",    "Radiohead",    "The Strokes",    "Vampire Weekend",    "The War on Drugs",    "Wilco",    "Elliott Smith",    "Modest Mouse",    "Neutral Milk Hotel",    "Pavement",    "Sonic Youth",    "Of Monsters and Men",    "The Pixies",    "The Smiths",    "Talking Heads",    "Arctic Monkeys"]
rnb_female_artists = [    "Destiny's Child",    "India.Arie",    "Mary J. Blige",    "Erykah Badu",    "Alicia Keys",    "SZA",    "Janelle Monáe",    "Solange",    "H.E.R.",    "Brandy",    "TLC",    "Janet Jackson",    "Whitney Houston",    "En Vogue",    "Chaka Khan",    "Diana Ross",    "Aretha Franklin",    "Gladys Knight",    "Tina Turner",    "Donna Summer"]
rnb_male_artists = [    "Michael Jackson",    "Prince",    "Stevie Wonder",    "Marvin Gaye",    "Al Green",    "Donny Hathaway",    "Sam Cooke",    "Otis Redding",    "Luther Vandross",    "R. Kelly",    "Usher",    "Chris Brown",    "The Weeknd",    "Frank Ocean",    "Miguel",    "D'Angelo",    "Maxwell",    "Boyz II Men",    "New Edition",    "The Temptations"]
EDM_female_artists = [    "Alison Wonderland",    "Rezz",    "Nervo",    "The Black Madonna",    "Nina Kraviz",    "Charlotte de Witte",    "Peggy Gou",    "Amelie Lens",    "Mija",    "Anna Lunoe",    "Honey Dijon",    "Annie Mac",    "Mija",    "Hannah Wants",    "Nicole Moudaber",    "Maya Jane Coles",    "Ellen Allien",    "Miss Kittin",    "Gorgon City",    "Disclosure"]
EDM_male_artists = [    "Calvin Harris",    "David Guetta",    "Tiësto",    "Armin van Buuren",    "Martin Garrix",    "Deadmau5",    "Steve Aoki",    "Avicii",    "Skrillex",    "The Chainsmokers",    "Marshmello",    "Zedd",    "Diplo",    "Afrojack",    "Axwell",    "Hardwell",    "Kaskade",    "Above & Beyond",    "Eric Prydz",    "Paul Oakenfold"]
metal_female_artists = [    "Lzzy Hale (Halestorm)",    "Angela Gossow (Arch Enemy)",    "Maria Brink (In This Moment)",    "Tarja Turunen (formerly of Nightwish)",    "Cristina Scabbia (Lacuna Coil)",    "Floor Jansen (Nightwish)",    "Simone Simons (Epica)",    "Tatiana Shmailyuk (Jinjer)",    "Alissa White-Gluz (Arch Enemy)",    "Amy Lee (Evanescence)",    "Sharon den Adel (Within Temptation)",    "Liv Kristine (Leaves' Eyes)",    "Anneke van Giersbergen (formerly of The Gathering)",    "Charlotte Wessels (Delain)",    "Doro Pesch (formerly of Warlock)",    "Veronica Freeman (Benedictum)",    "Ailyn (Sirenia)",    "Heidi Parviainen (formerly of Amberian Dawn)",    "Amanda Somerville (Avantasia)",    "Marta Gabriel (Crystal Viper)"]
metal_male_artists = [    "James Hetfield (Metallica)",    "Ozzy Osbourne (Black Sabbath)",    "Bruce Dickinson (Iron Maiden)",    "Rob Halford (Judas Priest)",    "Ronnie James Dio (Rainbow, Black Sabbath, Dio)",    "Mikael Akerfeldt (Opeth)",    "Tom Araya (Slayer)",    "Chuck Schuldiner (Death)",    "Tony Iommi (Black Sabbath)",    "Dave Mustaine (Megadeth)",    "Max Cavalera (Sepultura, Soulfly)",    "Devin Townsend (Strapping Young Lad, Devin Townsend Project)",    "Tomas Lindberg (At The Gates)",    "Myles Kennedy (Alter Bridge)",    "Tobias Sammet (Edguy, Avantasia)",    "Floor Jansen (Nightwish)",    "Mikael Stanne (Dark Tranquillity)",    "Alexi Laiho (Children of Bodom)",    "Joey Belladonna (Anthrax)",    "Johan Hegg (Amon Amarth)"]

# %%
import pandas as pd
col_names = ["MUSIC GENRE", "ARTIST GENDER"]
name = "SONG "
for i in range(1, 1001):
    col_names.append(name + str(i))
dataset = pd.DataFrame(columns=col_names)
dataset.head()

#pop_female_artists
base_record = ["POP", "FEMALE"]
for female_artist in pop_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["POP", "MALE"]
for male_artist in pop_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ROCK", "FEMALE"]
for female_artist in rock_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ROCK", "MALE"]
for male_artist in rock_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RAP", "FEMALE"]
for female_artist in rap_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RAP", "MALE"]
for male_artist in rap_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["COUNTRY", "FEMALE"]
for female_artist in country_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["COUNTRY", "MALE"]
for male_artist in country_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ALTERNATIVE INDIE", "FEMALE"]
for female_artist in alternative_indie_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["ALTERNATIVE INDIE", "MALE"]
for male_artist in alternative_indie_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RnB", "FEMALE"]
for female_artist in rnb_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["RnB", "MALE"]
for male_artist in rnb_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["EDM", "FEMALE"]
for female_artist in edm_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["EDM", "MALE"]
for male_artist in edm_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["METAL", "FEMALE"]
for female_artist in metal_female_artists:
    artist = genius.search_artist(female_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record 

base_record = ["METAL", "MALE"]
for male_artist in metal_male_artists:
    artist = genius.search_artist(male_artist, max_songs=50, sort='popularity')
    songs = artist.songs
    for song in songs:
        song = song.lyrics.replace('\n',' ')
        song = song.split()
        base_record.append(song)

print(len(base_record))
dataset.loc[len(dataset)] = base_record
